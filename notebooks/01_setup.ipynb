# %%
# !uv add kagglehub
# Out:
# Resolved 13 packages in 639ms
# Prepared 5 packages in 438ms
# Installed 10 packages in 147ms
#  + certifi==2026.5.20
#  + charset-normalizer==3.4.7
#  + idna==3.16
#  + kagglehub==1.0.1
#  + kagglesdk==0.1.23
#  + protobuf==7.35.0
#  + pyyaml==6.0.3
#  + requests==2.34.2
#  + tqdm==4.67.3
#  + urllib3==2.7.0

# %%
import kagglehub

path = kagglehub.dataset_download(
    "pengbo00/home-fire-dataset",
    output_dir="../data",
    force_download=True,
)

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.70G/1.70G [02:55<00:00, 10.4MB/s]
# Extracting files...
# Path to dataset files: ../data
